# %%
'''
Program used to translate Breakbar's txt file into wikitext.
The only edits that should be made are to the values of the variables near the top: fileName, currentYearAndMonth, and year.
(unless you want to try to improve the code)
The output is produced in the console (which should allow enough lines of output to be displayed if you use Google Colab or VS Code).
'''
import urllib

fileName = 'EP Daily Challenges.txt' #change depending on the name you want for Breakbar's txt file

urllib.request.urlretrieve('https://github.com/The-breakbar/Entry-Point-Wiki-Bot/raw/main/utils/DailyChallengeList.txt', fileName)

currentYearAndMonth = '2024-10' #must be in the format "YYYY-MM"
year = '2024' #change manually for the year you want the wikitext for
#currently, the txt file covers the end of 2022 to most of 2025

with open(fileName) as fin:
    while True:
        line = fin.readline()
        if line == '': #stops the loop when there's no more lines to read
            break
        date = line[:line.index(',')]

        if date[:4] == year: #checks if the year matches the specified year
            line = line[line.index(',') + 1:]
            mission = line[:line.index(',')]
            line = line[line.index(',') + 1:]
            tactic = line[:line.index(',')]
            line = line[line.index(',') + 1:]
            color1 = line[:line.index(',')]
            line = line[line.index(',') + 1:]
            mod1 = line[:line.index(',')]
            mod1 = 'Takedown Limit (4)' if mod1 == 'Takedown Limit' else 'Takedown Limit (6)' if mod1 == 'Takedown Limit 6' else mod1
            line = line[line.index(',') + 1:]
            color2 = line[:line.index(',')]
            line = line[line.index(',') + 1:]
            mod2 = line[:line.index(',')]
            mod2 = 'Takedown Limit (4)' if mod2 == 'Takedown Limit' else 'Takedown Limit (6)' if mod2 == 'Takedown Limit 6' else mod2
            line = line[line.index(',') + 1:]
            color3 = line[:line.index(',')]
            mod3 = line[line.index(',') + 1:].strip()
            mod3 = 'Takedown Limit (4)' if mod3 == 'Takedown Limit' else 'Takedown Limit (6)' if mod3 == 'Takedown Limit 6' else mod3

            if date[8:10] == '01': #first day of the month
                if date[5:7] == '01': #first month of the year
                    print(f"'''Daily Challenges''' from {year} will be displayed here.\n\n===January",end='')
                else:
                    match date[5:7]:
                        case '02':
                            print('|}\n===February',end='')
                        case '03':
                            print('|}\n===March',end='')
                        case '04':
                            print('|}\n===April',end='')
                        case '05':
                            print('|}\n===May',end='')
                        case '06':
                            print('|}\n===June',end='')
                        case '07':
                            print('|}\n===July',end='')
                        case '08':
                            print('|}\n===August',end='')
                        case '09':
                            print('|}\n===September',end='')
                        case '10':
                            print('|}\n===October',end='')
                        case '11':
                            print('|}\n===November',end='')
                        case '12':
                            print('|}\n===December',end='')
                        case _:
                            raise ValueError('The part in the txt file corresponding with the month was invalid.')
                print(f' {year}===\n{{| class="fandom-table article-table mw-collapsible mw-collapsed" ',end='')

                if date[:7] == currentYearAndMonth: #current year and current month
                    print('data-expandtext="Show Previous and Upcoming Challenges" data-collapsetext="Hide Previous and Upcoming Challenges"')
                elif int(year) < int(currentYearAndMonth[:4]) or (int(year) == int(currentYearAndMonth[:4]) and int(date[5:7]) < int(currentYearAndMonth[5:7])):
                    #earlier year OR same year but earlier month
                    print('data-expandtext="Show Previous Challenges" data-collapsetext="Hide Previous Challenges"')
                else: #current year and later month OR later year
                    print('data-expandtext="Show Upcoming Challenges" data-collapsetext="Hide Upcoming Challenges"')
                print('!Date\n!Mission\n!Tactic\n!Modifiers')

            print('|-\n!' + date + '\n|',end='')

            if mission == 'The Scientist' and mod1 == 'No Suppressors' and mod2 == 'Hidden UI' and mod3 == 'No Knockouts': #invalid modifier combinations
                print('The Scientist\n|Stealth\n|<span class=challenge-green>Fog</span>, <span class=challenge-green>No Suppressors</span>, <span class=challenge-purple>Hidden UI</span>')
            elif mission == 'The Scientist' and (mod1 == 'No Suppressors' or mod2 == 'No Suppressors') and mod3 == 'No Knockouts':
                match color2:
                    case 'G':
                        print(f'The Scientist\n|Stealth\n|<span class=challenge-green>{mod1}</span>, <span class=challenge-green>{mod2}</span>, <span class=challenge-purple>Hidden UI</span>')
                    case 'B':
                        print(f'The Scientist\n|Stealth\n|<span class=challenge-green>{mod1}</span>, <span class=challenge-blue>{mod2}</span>, <span class=challenge-purple>Hidden UI</span>')
                    case 'P':
                        print(f'The Scientist\n|Stealth\n|<span class=challenge-green>{mod1}</span>, <span class=challenge-purple>{mod2}</span>, <span class=challenge-purple>Hidden UI</span>')
                    case _:
                        raise ValueError("The part in the txt file corresponding with the second modifier's color was invalid.")
            else:
                if mission == 'The Auction' or mission == 'The Gala' or mission == 'The Cache' or mission == 'The Setup' or mission == 'The Lockup' or mission == 'The Score':
                    print('{{Robux}} ',end='')

                match color1:
                    case 'G':
                        print(f'{mission}\n|{tactic}\n|<span class=challenge-green>{mod1}</span>, ',end='')
                    case 'B':
                        print(f'{mission}\n|{tactic}\n|<span class=challenge-blue>{mod1}</span>, ',end='')
                    case 'P':
                        print(f'{mission}\n|{tactic}\n|<span class=challenge-purple>{mod1}</span>, ',end='')
                    case 'R':
                        print(f'{mission}\n|{tactic}\n|<span class=challenge-red>{mod1}</span>, ',end='')
                    case _:
                        raise ValueError("The part in the txt file corresponding with the first modifier's color was invalid.")

                match color2:
                    case 'G':
                        print(f'<span class=challenge-green>{mod2}</span>, ',end='')
                    case 'B':
                        print(f'<span class=challenge-blue>{mod2}</span>, ',end='')
                    case 'P':
                        print(f'<span class=challenge-purple>{mod2}</span>, ',end='')
                    case 'R':
                        print(f'<span class=challenge-red>{mod2}</span>, ',end='')
                    case _:
                        raise ValueError("The part in the txt file corresponding with the second modifier's color was invalid.")

                match color3:
                    case 'G':
                        print(f'<span class=challenge-green>{mod3}</span>')
                    case 'B':
                        print(f'<span class=challenge-blue>{mod3}</span>')
                    case 'P':
                        print(f'<span class=challenge-purple>{mod3}</span>')
                    case 'R':
                        print(f'<span class=challenge-red>{mod3}</span>')
                    case _:
                        raise ValueError("The part in the txt file corresponding with the third modifier's color was invalid.")
    print('|}')
# Out:
# '''Daily Challenges''' from 2024 will be displayed here.
#
# ===January 2024===
# {| class="fandom-table article-table mw-collapsible mw-collapsed" data-expandtext="Show Previous Challenges" data-collapsetext="Hide Previous Challenges"
# !Date
# !Mission
# !Tactic
# !Modifiers
# |-
# !2024-01-01
# |The Blacksite
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-01-02
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-01-03
# |The Financier
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>One Shot</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-01-04
# |The Killhouse
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-01-05
# |The Deposit
# |Stealth
# |<span class=challenge-blue>Extra Cameras</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Reinforced Cameras</span>
# |-
# !2024-01-06
# |The Scientist
# |Stealth
# |<span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-red>No Knockouts</span>
# |-
# !2024-01-07
# |{{Robux}} The Score
# |Loud
# |<span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-01-08
# |Black Dusk
# |Loud
# |<span class=challenge-blue>No Heavy Armor</span>, <span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-purple>Aegis Academy</span>
# |-
# !2024-01-09
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-01-10
# |The Scientist
# |Stealth
# |<span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Hidden UI</span>, <span class=challenge-red>No Knockouts</span>
# |-
# !2024-01-11
# |The Deposit
# |Loud
# |<span class=challenge-green>Boarded Up</span>, <span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>No Equipment Bags</span>
# |-
# !2024-01-12
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-green>Fog</span>, <span class=challenge-blue>Bloodless</span>
# |-
# !2024-01-13
# |The Blacksite
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-01-14
# |The Killhouse
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Unintimidating</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-01-15
# |The SCRS
# |Stealth
# |<span class=challenge-blue>Extra Cameras</span>, <span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-purple>No Lockpicks</span>
# |-
# !2024-01-16
# |The Financier
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>One Shot</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-01-17
# |{{Robux}} The Lockup
# |Stealth
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-01-18
# |The Deposit
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-green>Misplaced Gear</span>, <span class=challenge-blue>No Hybrid Classes</span>
# |-
# !2024-01-19
# |The SCRS
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>No Heavy Armor</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-01-20
# |The Financier
# |Loud
# |<span class=challenge-green>Boarded Up</span>, <span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-red>Explosive Revenge</span>
# |-
# !2024-01-21
# |The Lakehouse
# |Loud
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-01-22
# |{{Robux}} The Auction
# |Stealth
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-red>No Disguise</span>
# |-
# !2024-01-23
# |The Blacksite
# |Stealth
# |<span class=challenge-blue>No Scrambler</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-01-24
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-purple
# |Loud
# |<span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-blue>No Heavy Armor</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-08-15
# |The Financier
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-08-16
# |The Blacksite
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-08-17
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-08-18
# |The SCRS
# |Stealth
# |<span class=challenge-green>Misplaced Gear</span>, <span class=challenge-blue>Bloodless</span>, <span class=challenge-purple>Reinforced Cameras</span>
# |-
# !2024-08-19
# |{{Robux}} The Gala
# |Stealth
# |<span class=challenge-blue>Heavy Bags</span>, <span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-08-20
# |The Withdrawal
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-red>No Moving Bodies</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-08-21
# |The Lakehouse
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-green>Boarded Up</span>, <span class=challenge-purple>Less Health</span>
# |-
# !2024-08-22
# |The Killhouse
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-purple>One Shot</span>
# |-
# !2024-08-23
# |The Deposit
# |Stealth
# |<span class=challenge-blue>Extra Cameras</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-purple>Unintimidating</span>
# |-
# !2024-08-24
# |{{Robux}} The Setup
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-red>No Disguise</span>
# |-
# !2024-08-25
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-08-26
# |The Lakehouse
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-purple>Unintimidating</span>, <span class=challenge-purple>Reinforced Cameras</span>
# |-
# !2024-08-27
# |The Deposit
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-08-28
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Small Arms Only</span>, <span class=challenge-blue>Glass Cannon</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-08-29
# |{{Robux}} The Gala
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>No Scrambler</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-08-30
# |The SCRS
# |Loud
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Less Health</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-08-31
# |The Financier
# |Loud
# ...
# |<span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-purple>Inexperienced</span>
# |-
# !2024-10-12
# |The Deposit
# |Stealth
# |<span class=challenge-blue>Extra Cameras</span>, <span class=challenge-blue>Weapon Scanners</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-10-13
# |{{Robux}} The Lockup
# |Stealth
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Unintimidating</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-10-14
# |The Withdrawal
# |Loud
# |<span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-red>Explosive Revenge</span>
# |-
# !2024-10-15
# |The Financier
# |Stealth
# |<span class=challenge-blue>No Interrogation</span>, <span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-10-16
# |The Blacksite
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-blue>Unskilled</span>
# |-
# !2024-10-17
# |The Deposit
# |Loud
# |<span class=challenge-green>Boarded Up</span>, <span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>Glass Cannon</span>
# |-
# !2024-10-18
# |{{Robux}} The Gala
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>Bloodless</span>, <span class=challenge-blue>Heavy Bags</span>
# |-
# !2024-10-19
# |The Scientist
# |Loud
# |<span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-purple>Flashbang Revenge</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-10-20
# |Black Dusk
# |Loud
# |<span class=challenge-purple>Less Health</span>, <span class=challenge-red>Explosive Flashbangs</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-10-21
# |The SCRS
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-purple>Hidden UI</span>, <span class=challenge-purple>One Shot</span>
# |-
# !2024-10-22
# |The Lakehouse
# |Stealth
# |<span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-purple>No Lockpicks</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-10-23
# |{{Robux}} The Setup
# |Stealth
# |<span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-10-24
# |The Scientist
# |Loud
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-10-25
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-10-26
# |The Blacksite
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-10-27
# |The Deposit
# |Loud
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-blue>Armera Arsenal</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-10-28
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-10-29
# |The SCRS
# |Stealth
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>Extra Cameras</span>, <span class=challenge-purple>Unintimidating</span>
# |-
# !2024-10-30
# |The Financier
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-purple>Faster Detection</span>, <span class=challenge-purple>No Lockpicks</span>
# |-
# !2024-10-31
# |The Lakehouse
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |}
# ===November 2024===
# {| class="fandom-table article-table mw-collapsible mw-collapsed" data-expandtext="Show Upcoming Challenges" data-collapsetext="Hide Upcoming Challenges"
# !Date
# !Mission
# !Tactic
# !Modifiers
# |-
# !2024-11-01
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Small Arms Only</span>, <span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-purple>Aegis Academy</span>
# |-
# !2024-11-02
# |{{Robux}} The Lockup
# |Loud
# |<span class=challenge-blue>No Equipment Bags</span>, <span class=challenge-purple>Less Health</span>, <span class=challenge-purple>One Shot</span>
# |-
# !2024-11-03
# |The Withdrawal
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>No Hybrid Classes</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-11-04
# |The Blacksite
# |Stealth
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-11-05
# |The Scientist
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-11-06
# |Black Dusk
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-11-07
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-11-08
# |The Financier
# |Loud
# |<span class=challenge-blue>Small Arms Only</span>, <span class=challenge-blue>No Equipment Bags</span>, <span class=challenge-purple>Less Health</span>
# |-
# !2024-11-09
# |The SCRS
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Unintimidating</span>
# |-
# !2024-11-10
# |The Deposit
# |Loud
# |<span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-11-11
# |The Killhouse
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-blue>No Interrogation</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-11-12
# |{{Robux}} The Setup
# |Stealth
# |<span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>No Lockpicks</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-11-13
# |The SCRS
# |Stealth
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-11-14
# |The Blacksite
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>Hidden UI</span>, <span class=challenge-red>Explosive Revenge</span>
# |-
# !2024-11-15
# |Black Dusk
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-blue>Armera Arsenal</span>, <span class=challenge-blue>Reinforced Doors</span>
# |-
# !2024-11-16
# |The Withdrawal
# |Loud
# |<span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-purple>Flashbang Revenge</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-11-17
# |{{Robux}} The Auction
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-red>No Disguise</span>
# |-
# !2024-11-18
# |The Scientist
# |Stealth
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-red>No Knockouts</span>
# |-
# !2024-11-19
# |The Lakehouse
# |Loud
# |<span class=challenge-blue>Small Arms Only</span>, <span class=challenge-blue>Glass Cannon</span>, <span class=challenge-blue>No Heavy Armor</span>
# |-
# !2024-11-20
# |The Killhouse
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>No Interrogation</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-11-21
# |The Financier
# |Stealth
# |<span class=challenge-blue>Bloodless</span>, <span class=challenge-blue>No Hybrid Classes</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-11-22
# |{{Robux}} The Lockup
# |Stealth
# |<span class=challenge-purple>No Lockpicks</span>, <span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-red>Takedown Limit (4)</span>
# |-
# !2024-11-23
# |The SCRS
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-blue>No Equipment Bags</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-11-24
# |The Deposit
# |Loud
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Hidden UI</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-11-25
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>One Shot</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-11-26
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-purple>No Lockpicks</span>
# |-
# !2024-11-27
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Inexperienced</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-11-28
# |The Blacksite
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-11-29
# |The Lakehouse
# |Loud
# |<span class=challenge-green>Boarded Up</span>, <span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-purple>Weaker Medkits</span>
# |-
# !2024-11-30
# |The Financier
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>Bloodless</span>, <span class=challenge-purple>Unintimidating</span>
# |}
# ===December 2024===
# {| class="fandom-table article-table mw-collapsible mw-collapsed" data-expandtext="Show Upcoming Challenges" data-collapsetext="Hide Upcoming Challenges"
# !Date
# !Mission
# !Tactic
# !Modifiers
# |-
# !2024-12-01
# |The Killhouse
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-blue>Glass Cannon</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-12-02
# |{{Robux}} The Score
# |Loud
# |<span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-purple>Aegis Academy</span>, <span class=challenge-red>Explosive Revenge</span>
# |-
# !2024-12-03
# |The Killhouse
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>One Shot</span>, <span class=challenge-purple>Less Health</span>
# |-
# !2024-12-04
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Armera Arsenal</span>, <span class=challenge-blue>No Hybrid Classes</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-12-05
# |The Scientist
# |Loud
# |<span class=challenge-blue>Glass Cannon</span>, <span class=challenge-purple>Aegis Academy</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-12-06
# |The Deposit
# |Stealth
# |<span class=challenge-green>Misplaced Gear</span>, <span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-12-07
# |{{Robux}} The Auction
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-12-08
# |The SCRS
# |Loud
# |<span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-12-09
# |The Blacksite
# |Stealth
# |<span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-12-10
# |The Withdrawal
# |Stealth
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Reinforced Cameras</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-12-11
# |The Financier
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-purple>No Lockpicks</span>
# |-
# !2024-12-12
# |{{Robux}} The Score
# |Loud
# |<span class=challenge-green>No Aegis Armor</span>, <span class=challenge-purple>Flashbang Revenge</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-12-13
# |The SCRS
# |Stealth
# |<span class=challenge-blue>Extra Cameras</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-12-14
# |The Financier
# |Loud
# |<span class=challenge-blue>No Equipment Bags</span>, <span class=challenge-purple>Weaker Medkits</span>, <span class=challenge-purple>Flashbang Revenge</span>
# |-
# !2024-12-15
# |The Withdrawal
# |Loud
# |<span class=challenge-blue>Flashbang Frenzy</span>, <span class=challenge-purple>One Shot</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-12-16
# |The Lakehouse
# |Stealth
# |<span class=challenge-blue>No Interrogation</span>, <span class=challenge-purple>Inexperienced</span>, <span class=challenge-purple>Hidden Detection Bars</span>
# |-
# !2024-12-17
# |{{Robux}} The Cache
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-blue>Bloodless</span>, <span class=challenge-purple>Reinforced Cameras</span>
# |-
# !2024-12-18
# |The Scientist
# |Loud
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>No Heavy Armor</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-12-19
# |Black Dusk
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Aegis Academy</span>, <span class=challenge-red>Shield Swarm</span>
# |-
# !2024-12-20
# |The Deposit
# |Loud
# |<span class=challenge-blue>Small Arms Only</span>, <span class=challenge-red>Explosive Revenge</span>, <span class=challenge-red>No Explosives</span>
# |-
# !2024-12-21
# |The Blacksite
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Fifteen Minutes</span>
# |-
# !2024-12-22
# |{{Robux}} The Score
# |Loud
# |<span class=challenge-blue>Glass Cannon</span>, <span class=challenge-blue>Criminal Arsenal</span>, <span class=challenge-blue>Mandatory Headshots</span>
# |-
# !2024-12-23
# |Black Dusk
# |Loud
# |<span class=challenge-blue>No Heavy Armor</span>, <span class=challenge-purple>Aegis Academy</span>, <span class=challenge-red>Explosive Revenge</span>
# |-
# !2024-12-24
# |The Blacksite
# |Loud
# |<span class=challenge-blue>Cascade Arsenal</span>, <span class=challenge-purple>Less Health</span>, <span class=challenge-red>Explosive Flashbangs</span>
# |-
# !2024-12-25
# |The Withdrawal
# |Stealth
# |<span class=challenge-green>Fog</span>, <span class=challenge-blue>Reinforced Doors</span>, <span class=challenge-purple>Hidden UI</span>
# |-
# !2024-12-26
# |The Scientist
# |Stealth
# |<span class=challenge-blue>Reinforced Locks</span>, <span class=challenge-blue>Heavy Bags</span>, <span class=challenge-purple>Reinforced Cameras</span>
# |-
# !2024-12-27
# |{{Robux}} The Auction
# |Stealth
# |<span class=challenge-blue>No Scrambler</span>, <span class=challenge-purple>Hidden Detection Bars</span>, <span class=challenge-red>No Disguise</span>
# |-
# !2024-12-28
# |The Deposit
# |Stealth
# |<span class=challenge-blue>No Interrogation</span>, <span class=challenge-purple>Fifteen Minutes</span>, <span class=challenge-red>No Moving Bodies</span>
# |-
# !2024-12-29
# |The Killhouse
# |Stealth
# |<span class=challenge-green>No Suppressors</span>, <span class=challenge-blue>Unskilled</span>, <span class=challenge-purple>Faster Detection</span>
# |-
# !2024-12-30
# |The Financier
# |Stealth
# |<span class=challenge-green>No Safecracking</span>, <span class=challenge-purple>Unintimidating</span>, <span class=challenge-purple>No Lockpicks</span>
# |-
# !2024-12-31
# |The Lakehouse
# |Loud
# |<span class=challenge-blue>Mandatory Headshots</span>, <span class=challenge-blue>Armera Arsenal</span>, <span class=challenge-red>Shield Swarm</span>
# |}
